# %% [markdown]
# Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/DataPath/Week 3 Python
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/DataPath/Week 3 Python'
# /content

# %%
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Super_cleaned_dataset1.csv')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#           Job Title  Salary Estimate  ... need_big_data  need_deep_learning
# 0    data scientist            154.0  ...         False               False
# 1    data scientist            154.0  ...         False                True
# 2    data scientist            154.0  ...         False               False
# 3    data scientist            154.0  ...         False               False
# 4    data scientist            154.0  ...         False               False
# ..              ...              ...  ...           ...                 ...
# 474  data scientist            136.0  ...         False               False
# 475  data scientist            136.0  ...          True               False
# 476  data scientist            136.0  ...         False               False
# 477  data scientist            136.0  ...          True                True
# 478  data scientist            136.0  ...         False               False
#
# [479 rows x 20 columns]

# %%
df['Location'].value_counts().tail(50)

# %%
df['State'] = df['Location'].apply(lambda x: x.split(', ')[-1])

# %%
df
# Out:
#           Job Title  Salary Estimate  ... need_deep_learning  State
# 0    data scientist            154.0  ...              False     MA
# 1    data scientist            154.0  ...               True     MA
# 2    data scientist            154.0  ...              False     NY
# 3    data scientist            154.0  ...              False     CA
# 4    data scientist            154.0  ...              False     MA
# ..              ...              ...  ...                ...    ...
# 474  data scientist            136.0  ...              False     MA
# 475  data scientist            136.0  ...              False     NJ
# 476  data scientist            136.0  ...              False     CA
# 477  data scientist            136.0  ...               True     CA
# 478  data scientist            136.0  ...              False     NY
#
# [479 rows x 21 columns]

# %%
df[df['Location']=='Remote']
# Out:
#           Job Title  Salary Estimate  ... need_deep_learning   State
# 12   data scientist            154.0  ...              False  Remote
# 139  data scientist             92.5  ...              False  Remote
# 219          others            185.0  ...              False  Remote
#
# [3 rows x 21 columns]

# %%
df.to_csv("State_blmbersih.csv")

# %%
def clean_states(x):
    if 'united states' in x.lower():
        return 'NY'
    elif 'new jersey' in x.lower():
        return 'NJ'
    elif 'california' in x.lower():
        return 'CA'
    elif 'texas' in x.lower():
        return 'TX'
    elif 'utah' in x.lower():
        return 'UT'
    else:
        return str(x)

df['State'] = df['State'].apply(clean_states)

# %%
df
# Out:
#           Job Title  Salary Estimate  ... need_deep_learning  State
# 0    data scientist            154.0  ...              False     MA
# 1    data scientist            154.0  ...               True     MA
# 2    data scientist            154.0  ...              False     NY
# 3    data scientist            154.0  ...              False     CA
# 4    data scientist            154.0  ...              False     MA
# ..              ...              ...  ...                ...    ...
# 474  data scientist            136.0  ...              False     MA
# 475  data scientist            136.0  ...              False     NJ
# 476  data scientist            136.0  ...              False     CA
# 477  data scientist            136.0  ...               True     CA
# 478  data scientist            136.0  ...              False     NY
#
# [479 rows x 21 columns]

# %% [markdown]
# NGETEST

# %%
#test nyoba 
dftest = pd.read_csv('State_blmbersih.csv')

# %%
def clean_states(x):
    if 'united states' in x.lower():
        return 'NY'
    elif 'new jersey' in x.lower():
        return 'NJ'
    elif 'california' in x.lower():
        return 'CA'
    elif 'texas' in x.lower():
        return 'TX'
    elif 'utah' in x.lower():
        return 'UT'
    else:
        return str(x)

dftest['State'] = dftest['State'].apply(clean_states)

# %%
dftest['need_python'][dftest['need_python']==True] = 1
dftest['need_python'][dftest['need_python']==False] = 0

dftest['need_excel'][dftest['need_excel']==True] = 1
dftest['need_excel'][dftest['need_excel']==False] = 0

dftest['need_hadoop'][dftest['need_hadoop']==True] = 1
dftest['need_hadoop'][dftest['need_hadoop']==False] = 0

dftest['need_spark'][dftest['need_spark']==True] = 1
dftest['need_spark'][dftest['need_spark']==False] = 0

dftest['need_tableau'][dftest['need_tableau']==True] = 1
dftest['need_tableau'][dftest['need_tableau']==False] = 0

dftest['need_big_data'][dftest['need_big_data']==True] = 1
dftest['need_big_data'][dftest['need_big_data']==False] = 0

dftest['need_deep_learning'][dftest['need_deep_learning']==True] = 1
dftest['need_deep_learning'][dftest['need_deep_learning']==False] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dftest
# Out:
#      Unnamed: 0       Job Title  ...  need_deep_learning State
# 0             0  data scientist  ...                 0.0    MA
# 1             1  data scientist  ...                 1.0    MA
# 2             2  data scientist  ...                 0.0    NY
# 3             3  data scientist  ...                 0.0    CA
# 4             4  data scientist  ...                 0.0    MA
# ..          ...             ...  ...                 ...   ...
# 474         474  data scientist  ...                 0.0    MA
# 475         475  data scientist  ...                 0.0    NJ
# 476         476  data scientist  ...                 0.0    CA
# 477         477  data scientist  ...                 1.0    CA
# 478         478  data scientist  ...                 0.0    NY
#
# [479 rows x 22 columns]

# %% [markdown]
# GAINING INSIGHTS

# %% [markdown]
# Average Salary Comparison Across States

# %%
df.groupby(['State'])[['Salary Estimate']].mean().sort_values('Salary Estimate').plot(kind='bar',figsize=(15,6))
plt.title('Average Salary Comparison Across States')
plt.xlabel('Average Salary')
plt.show()

# %% [markdown]
# Average Workload Comparison Across State

# %%
df.groupby(['State'])[['workload']].mean().sort_values('workload').plot(kind='bar',figsize=(15,6))
plt.title('Average Workload Comparison Across States')
plt.xlabel('workload')
plt.show()

# %% [markdown]
# Each of Needed Skills Across States

# %%
dftest1 = df.groupby(['State'])[['need_python', 'need_excel', 'need_hadoop', 'need_spark', 'need_tableau', 'need_big_data', 'need_deep_learning' ]].sum()

# %%
dftest1 = dftest1.T

# %%
for column in dftest1.columns:
  dftest1[column] = (100*dftest1[column] / (dftest1[column].sum()))

# %%
dftest1 = dftest1.T

# %%
dftest1.groupby(['State'])[['need_python', 'need_excel', 'need_hadoop', 'need_spark', 'need_tableau', 'need_big_data', 'need_deep_learning' ]].sum().plot(kind='bar',figsize=(20,8),stacked=True)
plt.title('Each of Needed Skills Across States (%)')
plt.show()
